# %%
import sys, os
ROOT = r"C:\Users\ADMIN\Desktop\NDM_Project"
os.chdir(ROOT)
print("CWD =", os.getcwd())
print("PY  =", sys.executable)
# Out:
# CWD = C:\Users\ADMIN\Desktop\NDM_Project
# PY  = C:\ProgramData\anaconda3\python.exe

# %%
try:
    import torch
    print("torch OK:", torch.__version__)
except Exception as e:
    print("torch FAIL:", e)
# Out:
# torch OK: 2.9.1+cpu

# %%
# %run .\src\run_phase7_cnn.py
# Out:
#   File ~\Desktop\NDM_Project\src\run_phase7_cnn.py:182
#     yb = yb.long()
#     ^
# TabError: inconsistent use of tabs and spaces in indentation

# %%
# %run .\src\run_phase7_cnn.py
# Out:
#   File ~\Desktop\NDM_Project\src\run_phase7_cnn.py:182
#     yb = yb.long()
#     ^
# TabError: inconsistent use of tabs and spaces in indentation

# %%
# %run .\src\run_phase7_cnn.py
# Out:
# ROOT   = C:\Users\ADMIN\Desktop\NDM_Project
# device = cpu
# cnn_cfg = {'seed': 42, 'seg_len': 4096, 'hop_len': 4096, 'batch_size': 64, 'epochs': 25, 'lr': 0.001, 'weight_decay': 0.0001, 'emb_dim': 128, 'device': 'auto'}
# spec_cfg = {'window_type': 'hamming', 'win_length': 512, 'hop_length': 256, 'n_fft': 512, 'use_mel': True, 'mel_bins': 64, 'fmin': 0.0, 'fmax': None, 'power': 2.0, 'log_eps': 1e-08, 'to_db': False}
# split sizes: {'train': 80, 'val': 10, 'test': 10}
# intersections: 0 0 0
#
# Building spectrogram tensors...
# Shapes: (880, 1, 64, 15) (110, 1, 64, 15) (110, 1, 64, 15)
# train norm mean/std: -11.046266555786133 3.303321646286011
# Classes: ['BF_007', 'BF_014', 'BF_021', 'H', 'IRF_007', 'IRF_014', 'IRF_021', 'ORF_007', 'ORF_014', 'ORF_021']
#
# Training...
# Epoch 01/25 | train_loss=1.7936 | val_loss=1.6202 | val_acc=0.4000 | val_f1=0.3382  <-- best
# Epoch 02/25 | train_loss=0.7458 | val_loss=0.7502 | val_acc=0.6364 | val_f1=0.5942  <-- best
# Epoch 03/25 | train_loss=0.2619 | val_loss=0.1490 | val_acc=0.9545 | val_f1=0.9521  <-- best
# Epoch 04/25 | train_loss=0.0514 | val_loss=0.0213 | val_acc=1.0000 | val_f1=1.0000  <-- best
# Epoch 05/25 | train_loss=0.0235 | val_loss=0.0204 | val_acc=1.0000 | val_f1=1.0000
# Epoch 06/25 | train_loss=0.0142 | val_loss=0.0441 | val_acc=0.9818 | val_f1=0.9817
# Epoch 07/25 | train_loss=0.0049 | val_loss=0.0029 | val_acc=1.0000 | val_f1=1.0000
# Epoch 08/25 | train_loss=0.0045 | val_loss=0.0019 | val_acc=1.0000 | val_f1=1.0000
# Epoch 09/25 | train_loss=0.0032 | val_loss=0.0042 | val_acc=1.0000 | val_f1=1.0000
# Epoch 10/25 | train_loss=0.0017 | val_loss=0.0008 | val_acc=1.0000 | val_f1=1.0000
# Epoch 11/25 | train_loss=0.0015 | val_loss=0.0016 | val_acc=1.0000 | val_f1=1.0000
# Epoch 12/25 | train_loss=0.0017 | val_loss=0.0006 | val_acc=1.0000 | val_f1=1.0000
# Epoch 13/25 | train_loss=0.0010 | val_loss=0.0010 | val_acc=1.0000 | val_f1=1.0000
# Epoch 14/25 | train_loss=0.0006 | val_loss=0.0010 | val_acc=1.0000 | val_f1=1.0000
# Epoch 15/25 | train_loss=0.0007 | val_loss=0.0005 | val_acc=1.0000 | val_f1=1.0000
# Epoch 16/25 | train_loss=0.0008 | val_loss=0.0006 | val_acc=1.0000 | val_f1=1.0000
# Epoch 17/25 | train_loss=0.0011 | val_loss=0.0006 | val_acc=1.0000 | val_f1=1.0000
# Epoch 18/25 | train_loss=0.0007 | val_loss=0.0007 | val_acc=1.0000 | val_f1=1.0000
# Epoch 19/25 | train_loss=0.0005 | val_loss=0.0006 | val_acc=1.0000 | val_f1=1.0000
# Epoch 20/25 | train_loss=0.0006 | val_loss=0.0004 | val_acc=1.0000 | val_f1=1.0000
# Epoch 21/25 | train_loss=0.0006 | val_loss=0.0004 | val_acc=1.0000 | val_f1=1.0000
# Epoch 22/25 | train_loss=0.0004 | val_loss=0.0005 | val_acc=1.0000 | val_f1=1.0000
# Epoch 23/25 | train_loss=0.0004 | val_loss=0.0004 | val_acc=1.0000 | val_f1=1.0000
# Epoch 24/25 | train_loss=0.0005 | val_loss=0.0003 | val_acc=1.0000 | val_f1=1.0000
# Epoch 25/25 | train_loss=0.0004 | val_loss=0.0003 | val_acc=1.0000 | val_f1=1.0000
#
# Saved: C:\Users\ADMIN\Desktop\NDM_Project\results\cnn_baseline.pt
# Saved: C:\Users\ADMIN\Desktop\NDM_Project\results\cnn_train_log.json
#
# TEST: loss=0.0168 acc=1.0000 macro_f1=1.0000
# Saved: C:\Users\ADMIN\Desktop\NDM_Project\results\cm_cnn.png
# Saved: C:\Users\ADMIN\Desktop\NDM_Project\results\cnn_phase7_info.json
#
# PHASE 7 DONE.

# %%
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open(r"C:\Users\ADMIN\Desktop\NDM_Project\results\cm_cnn.png")
plt.figure()
plt.imshow(img)
plt.axis("off")
plt.show()
